# %% [markdown]
# #Desafio de Diccionario
#
# #####Copa Mundial FIFA
#
# Deberás crear un diccionario que almacene a los ganadores de la Copa Mundial de la FIFA desde el año 1990 al 2018. Y mostrarlo por pantalla.

# %%
campeones = {1990:'Alemania', 1994:'Brasil', 1998:'Francia', 2002:'Brasil', 2006:'Italia', 2010:'España', 2014:'Alemania', 2018:'Francia'}
campeones[2022] = 'Argentina'
for clave, valor in campeones.items():
  print(f'{clave}: {valor}')
# Out:
# 1990: Alemania
# 1994: Brasil
# 1998: Francia
# 2002: Brasil
# 2006: Italia
# 2010: España
# 2014: Alemania
# 2018: Francia
# 2022: Argentina
