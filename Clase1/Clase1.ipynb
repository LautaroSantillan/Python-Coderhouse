# %%
print("El GTA VI va a ser una locura")
# Out:
# El GTA VI va a ser una locura

# %%
#Numeros en Python
print(1.83)
print(19)
# Out:
# 1.83
# 19

# %%
print("Esto es un ERROR:", 404)
#Calcular el area de un circulo
print(3.14*2*2)
# Out:
# Esto es un ERROR: 404
# 12.56

# %%
#Operaciones con n°
print("Teniendo los numeros 8 y 3")
print("La suma es", 8+3)
print("La resta es", 8-3)
print("La multiplicacion es", 8*3)
print("La division entre 8 y 3 es", 8/3)
print("La potencia de 8 al cubo es", 8**3)
print("El resto de dividir 8 entre 3 es", 8%3)
print("El cociente de dividir 8 entre 3 es", 8//3)
print("Orden de jerarquias =>", 4**3-4*5/2+20-(5*3)/4)
# Out:
# Teniendo los numeros 8 y 3
# La suma es 11
# La resta es 5
# La multiplicacion es 24
# La division entre 8 y 3 es 2.6666666666666665
# La potencia de 8 al cubo es 512
# El resto de dividir 8 entre 3 es 2
# El cociente de dividir 8 entre 3 es 2
# Orden de jerarquias => 70.25

# %%
#Variables
edad = 19
print('Yo tengo', edad, 'años')

x = 2020
x = 2021
x = 2022
x = 2023
print("Estamos en el año", x)
# Out:
# Yo tengo 19 años
# Estamos en el año 2023

# %%
#Type => Sirve para mostrarnos que tipo de dato es la variable
x = "Hello World!"
type(x)
# Out:
# str

# %%
#Input => Permite que un usuario ingrese valores a una variable
nombre = input("Como te llamas? ")
print(nombre)
edad = int(input("Cuantos años tenes? "))
print("La edad es de", edad)
altura = float(input("Cuanto medis? "))
print(nombre, "mide", altura, "mt")
# Out:
# Como te llamas? Lautaro
# Lautaro
# Cuantos años tenes? 19
# La edad es de 19
# Cuanto medis? 1.83
# Lautaro mide 1.83 mt

# %%
int(8.8) #Pasa a ser 8
type(int(8.8))
# Out:
# int

# %%
#Operaciones aritméticas con variables
cadena = 'Python'
cadena * 2 #PythonPython
cadena2 = "Esto es "
cadena2 + cadena
# Out:
# 'Esto es Python'

# %%
#Indexación de cadenas
cadena = "Python"
cadena[2] #t
cadena[-3]
# Out:
# 'h'

# %%
#Longitud de cadenas
palabra = "Hola, como estas?"
len(palabra)
# Out:
# 17

# %%
#Slicing => Rebanar string
cadena = "Pithon"
print(cadena)
cadena = cadena[0:1] + 'y' + cadena[2:]
print(cadena)
# Out:
# Pithon
# Python
