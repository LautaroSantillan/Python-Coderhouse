# %% [markdown]
# #Credito Bancario
#
# Aprobación de Crédito bancario
#
# ###Descripción de la actividad.
#
# Para aprobar un crédito, el cliente debe ser mayor de edad. Además, debe tener una antigüedad en el sistema financiero de mínimo 3 años y un ingreso mayor a 2500 dólares.  En caso no tenga la antigüedad suficiente, su ingreso mensual debe ser como mínimo 4000 dólares. Si no cumple ninguna de las condiciones, no se aprueba el crédito
#
# Datos iniciales
# * edad = 15
# * antigüedad = 10
# * ingreso = 1500

# %%
nombre = input("Ingrese su nombre: ")
edad = int(input("Ingrese su edad: "))
if edad >= 18:
  antiguedad = int(input("Ingrese su antiguedad en el sistema financiero: "))
  ingreso = int(input("Ingrese su salario en u$d: "))
  if (antiguedad >= 3) and (ingreso >= 2500):
    print(f'{nombre}: Usted queda aprobado para sacar un crédito')
  elif ingreso >= 4000:
    print(f'{nombre}: Usted queda aprobado para sacar un crédito')
  else:
    print(f'{nombre}: Usted no queda aprobado para sacar un crédito')
else:
  print(f'{nombre}: Usted no es mayor de edad')
# Out:
# Ingrese su nombre: Lautaro
# Ingrese su edad: 20
# Ingrese su antiguedad en el sistema financiero: 2
# Ingrese su salario en u$d: 4100
# Lautaro: Usted queda aprobado para sacar un crédito
