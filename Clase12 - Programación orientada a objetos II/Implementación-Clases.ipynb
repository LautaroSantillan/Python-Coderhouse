# %% [markdown]
# #Implementación en Python
#
# Clases desde DrawIO a Python
#
# ###Consigna: Implementar la Clase de Alumno, creada en la actividad anterior, directamente en Python
#
# ###Aclaraciones Generales:
# * El método imprimir, deberá mostrar por pantalla el nombre y la nota del estudiante.
# * El método resultado, evalúa la nota correspondiente del estudiante. Si el estudiante saca menos de 5 puntos desaprueba la materia, más de 5 puntos aprueba. **Tip:** Para la realización de este apartado, es necesario trabajar con estructuras condicionales.
# * Se deberá instanciar, al menos, dos objetos pertenecientes a la clase Alumno.

# %%
class Alumno:
  #Atributos
  def __init__(self, nombre, apellido, nota):
    self.nombre = nombre
    self.apellido = apellido
    self.nota = nota
  #Métodos
  def imprimir(self):
    print(f"Nota de {self.nombre} {self.apellido}: {self.nota}")

  def resultado(self):
    if self.nota <= 5:
      print(f"Estado de la materia - Alumno {self.apellido}: Desaprobado")
    else:
      print(f"Estado de la materia - Alumno {self.apellido}: Aprobado")

# %%
alumno1 = Alumno("Lautaro", "Santillan", 8)
alumno2 = Alumno("Nazareno", "Perez", 5)
alumno3 = Alumno("Gabriel", "Avalos", 3)

# %%
alumno1.resultado()
alumno2.imprimir()
alumno3.resultado()
# Out:
# Estado de la materia - Alumno Santillan: Aprobado
# Nota de Nazareno Perez: 5
# Estado de la materia - Alumno Avalos: Desaprobado
